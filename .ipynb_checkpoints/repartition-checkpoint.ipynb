# %%
selected, assignment, obj, scores = solve_assignment(
    scores_json,
    min_size=3,
    max_size=4,
    k_projects=6,     # force exactement K groupes
    lexicographic=False,    # une seule phase (le score est l'objectif)
)
assignment
# Out:
# {'2 -- Robot Tiki': ['24 -- Ariihau Temarii',
#   '25 -- Killian Temauri',
#   '26 -- Divine Tetaronia--mahagafanau',
#   '5 -- Mahé Gallard'],
#  '6 -- Chimie Extramet': ['13 -- Poehei Chagne',
#   '15 -- Taiamani Fauura',
#   '6 -- Hitiarii Hauata',
#   '9 -- Poeiti  Choung ping'],
#  '3 -- Station Météo': ['17 -- Havaiki Bossert',
#   '21 -- Manoa Nonoha',
#   '23 -- Ariinui Graffe',
#   '29 -- Tim Tumarae'],
#  '5 -- Chimie Accepe': ['10 -- Angélique Ellacott',
#   '12 -- Ridley Failloux',
#   '19 -- Keala Pierron',
#   '22 -- Ariimihinoa Lai ah che'],
#  '1 -- Totem': ['11 -- Keona Duval',
#   '14 -- Heremoana Dagues',
#   '27 -- Devan Tetuanui',
#   '28 -- Rahan Tchan'],
#  '4 -- Hydroponie': ['16 -- Jules Darcy',
#   '20 -- Eric Lao ky soi',
#   '7 -- Haitutini Haiti',
#   '8 -- Teani Cuzacq--carrasset']}

# %%
print("\n=== Solution avec K fixé =", 6, "(max de groupes de 4, règle dure) ===")
print("Projets sélectionnés :", sorted(selected), f"(K={len(selected)})")
for p in sorted(assignment):
    print(f"{p}  (n={len(assignment[p])})  ← {assignment[p]}")
print("Score total :", obj)
# Out:
# === Solution avec K fixé = 6 (max de groupes de 4, règle dure) ===
# Projets sélectionnés : ['1 -- Totem', '2 -- Robot Tiki', '3 -- Station Météo', '4 -- Hydroponie', '5 -- Chimie Accepe', '6 -- Chimie Extramet'] (K=6)
# 1 -- Totem  (n=4)  ← ['11 -- Keona Duval', '14 -- Heremoana Dagues', '27 -- Devan Tetuanui', '28 -- Rahan Tchan']
# 2 -- Robot Tiki  (n=4)  ← ['24 -- Ariihau Temarii', '25 -- Killian Temauri', '26 -- Divine Tetaronia--mahagafanau', '5 -- Mahé Gallard']
# 3 -- Station Météo  (n=4)  ← ['17 -- Havaiki Bossert', '21 -- Manoa Nonoha', '23 -- Ariinui Graffe', '29 -- Tim Tumarae']
# 4 -- Hydroponie  (n=4)  ← ['16 -- Jules Darcy', '20 -- Eric Lao ky soi', '7 -- Haitutini Haiti', '8 -- Teani Cuzacq--carrasset']
# 5 -- Chimie Accepe  (n=4)  ← ['10 -- Angélique Ellacott', '12 -- Ridley Failloux', '19 -- Keala Pierron', '22 -- Ariimihinoa Lai ah che']
# ...

# %%
styler = viz(scores, assignment, False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-814586a86b4b> in <module>
# ----> 1 styler = viz(scores, assignment, False)
#
# NameError: name 'scores' is not defined

# %%
display(styler)
