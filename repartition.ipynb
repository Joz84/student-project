# %%
from repartition import solve_assignment
import random
import math

# %%
random.seed(42)

students = [f"E{i}" for i in range(1, 24)]  # 25 élèves
all_projects = [f"P{j}" for j in range(1, 7)]  # 12 projets
scores = {}

# On simule des préférences : chaque élève tire 7 projets distincts et reçoit des notes 6..1
for e in students:
    prefs = random.sample(all_projects, 6)
    for rank, p in enumerate(prefs, start=1):
        scores[(e, p)] = 7 - rank  # 10 pour le 1er choix, 1 pour le 10e

print("\n=== Inputs ===")
print("students")
print(students)
print("all_projects")
print(all_projects)  
print("scores")
print(scores)
# Out:
# === Inputs ===
# students
# ['E1', 'E2', 'E3', 'E4', 'E5', 'E6', 'E7', 'E8', 'E9', 'E10', 'E11', 'E12', 'E13', 'E14', 'E15', 'E16', 'E17', 'E18', 'E19', 'E20', 'E21', 'E22', 'E23']
# all_projects
# ['P1', 'P2', 'P3', 'P4', 'P5', 'P6']
# scores
# {('E1', 'P6'): 6, ('E1', 'P1'): 5, ('E1', 'P5'): 4, ('E1', 'P3'): 3, ('E1', 'P2'): 2, ('E1', 'P4'): 1, ('E2', 'P2'): 6, ('E2', 'P6'): 5, ('E2', 'P1'): 4, ('E2', 'P3'): 3, ('E2', 'P4'): 2, ('E2', 'P5'): 1, ('E3', 'P1'): 6, ('E3', 'P6'): 5, ('E3', 'P5'): 4, ('E3', 'P4'): 3, ('E3', 'P3'): 2, ('E3', 'P2'): 1, ('E4', 'P5'): 6, ('E4', 'P2'): 5, ('E4', 'P4'): 4, ('E4', 'P1'): 3, ('E4', 'P6'): 2, ('E4', 'P3'): 1, ('E5', 'P1'): 6, ('E5', 'P2'): 5, ('E5', 'P4'): 4, ('E5', 'P5'): 3, ('E5', 'P3'): 2, ('E5', 'P6'): 1, ('E6', 'P2'): 6, ('E6', 'P3'): 5, ('E6', 'P1'): 4, ('E6', 'P4'): 3, ('E6', 'P6'): 2, ('E6', 'P5'): 1, ('E7', 'P3'): 6, ('E7', 'P6'): 5, ('E7', 'P5'): 4, ('E7', 'P1'): 3, ('E7', 'P2'): 2, ('E7', 'P4'): 1, ('E8', 'P4'): 6, ('E8', 'P1'): 5, ('E8', 'P3'): 4, ('E8', 'P6'): 3, ('E8', 'P2'): 2, ('E8', 'P5'): 1, ('E9', 'P6'): 6, ('E9', 'P1'): 5, ('E9', 'P5'): 4, ('E9', 'P3'): 3, ('E9', 'P4'): 2, ('E9', 'P2'): 1, ('E10', 'P1'): 6, ('E10', 'P2'): 5, ('E10', 'P6'): 4, ('E10', 'P5'): 3, ('E10', 'P3'): 2, ('E10', 'P4'): 1, ('E11', 'P6'): 6, ('E11', 'P3'): 5, ('E11', 'P2'): 4, ('E11', 'P4'): 3, ('E11', 'P5'): 2, ('E11', 'P1'): 1, ('E12', 'P6'): 6, ('E12', 'P3'): 5, ('E12', 'P1'): 4, ('E12', 'P5'): 3, ('E12', 'P4'): 2, ('E12', 'P2'): 1, ('E13', 'P2'): 6, ('E13', 'P4'): 5, ('E13', 'P5'): 4, ('E13', 'P6'): 3, ('E13', 'P1'): 2, ('E13', 'P3'): 1, ('E14', 'P1'): 6, ('E14', 'P2'): 5, ('E14', 'P6'): 4, ('E14', 'P5'): 3, ('E14', 'P3'): 2, ('E14', 'P4'): 1, ('E15', 'P1'): 6, ('E15', 'P2'): 5, ('E15', 'P3'): 4, ('E15', 'P6'): 3, ('E15', 'P5'): 2, ('E15', 'P4'): 1, ('E16', 'P6'): 6, ('E16', 'P4'): 5, ('E16', 'P2'): 4, ('E16', 'P5'): 3, ('E16', 'P1'): 2, ('E16', 'P3'): 1, ('E17', 'P6'): 6, ('E17', 'P5'): 5, ('E17', 'P3'): 4, ('E17', 'P4'): 3, ('E17', 'P2'): 2, ('E17', 'P1'): 1, ('E18', 'P3'): 6, ('E18', 'P2'): 5, ('E18', 'P5'): 4, ('E18', 'P6'): 3, ('E18', 'P4'): 2, ('E18', 'P1'): 1, ('E19', 'P1'): 6, ('E19', 'P6'): 5, ('E19', 'P2'): 4, ('E19', 'P3'): 3, ('E19', 'P5'): 2, ('E19', 'P4'): 1, ('E20', 'P5'): 6, ('E20', 'P1'): 5, ('E20', 'P4'): 4, ('E20', 'P2'): 3, ('E20', 'P3'): 2, ('E20', 'P6'): 1, ('E21', 'P5'): 6, ('E21', 'P1'): 5, ('E21', 'P6'): 4, ('E21', 'P3'): 3, ('E21', 'P2'): 2, ('E21', 'P4'): 1, ('E22', 'P1'): 6, ('E22', 'P3'): 5, ('E22', 'P4'): 4, ('E22', 'P6'): 3, ('E22', 'P2'): 2, ('E22', 'P5'): 1, ('E23', 'P6'): 6, ('E23', 'P3'): 5, ('E23', 'P2'): 4, ('E23', 'P5'): 3, ('E23', 'P1'): 2, ('E23', 'P4'): 1}

# %%
# CAS 2 (optionnel) : imposer K = ceil(N/4) pour forcer le maximum possible de groupes de 4
K_force = math.ceil(len(students) / 4)  # pour 25 → 7
selected2, assignment2, obj2 = solve_assignment(
    scores,
    students=students,
    projects=all_projects,
    min_size=3,
    max_size=4,
    k_projects=K_force,     # force exactement K groupes
    lexicographic=False,    # une seule phase (le score est l'objectif)
)
assignment2
# Out:
# {'P3': ['E18', 'E22', 'E23', 'E7'],
#  'P4': ['E13', 'E16', 'E8'],
#  'P6': ['E1', 'E11', 'E12', 'E9'],
#  'P5': ['E17', 'E20', 'E21', 'E4'],
#  'P1': ['E10', 'E15', 'E19', 'E3'],
#  'P2': ['E14', 'E2', 'E5', 'E6']}

# %%
print("\n=== Solution avec K fixé =", K_force, "(max de groupes de 4, règle dure) ===")
print("Projets sélectionnés :", sorted(selected2), f"(K={len(selected2)})")
for p in sorted(assignment2):
    print(f"{p}  (n={len(assignment2[p])})  ← {assignment2[p]}")
print("Score total :", obj2)

# %%
# -*- coding: utf-8 -*-
import pandas as pd
import numpy as np
from matplotlib.colors import LinearSegmentedColormap

# ===== Données =====
scores = scores
assignations = assignment

# ===== Construction du DataFrame pivoté (lignes E??, colonnes P??) =====
df = pd.Series(scores).unstack()  # colonnes = P??, index = E??
# Tri naturel E1..E23 et P1..P6
df = df.loc[sorted(df.index, key=lambda x: int(x[1:])),
            sorted(df.columns, key=lambda x: int(x[1:]))]

# ===== Colormap blanc -> vert foncé =====
# (blanc pour les plus faibles, vert foncé pour les plus forts)
cmap = LinearSegmentedColormap.from_list(
    "white_to_green",
    ["#ffffff", "#a5d6a7", "#66bb6a", "#2e7d32"]  # clair -> foncé
)

# ===== Fonction de style : encadrement des cellules assignées =====
def highlight_assigned(dataframe: pd.DataFrame) -> pd.DataFrame:
    styles = pd.DataFrame("", index=dataframe.index, columns=dataframe.columns)
    # Inverser la dict pour trouver, pour chaque étudiant, son projet assigné
    etu_to_proj = {}
    for p, etus in assignations.items():
        for e in etus:
            etu_to_proj[e] = p
    # Appliquer le bord noir épais
    for e, p in etu_to_proj.items():
        if e in styles.index and p in styles.columns:
            styles.loc[e, p] = "border: 3px solid black"
    return styles

# ===== Création du Styler =====
styler = (
    df.style
      .format("{:.0f}")                         
      .background_gradient(cmap=cmap, axis=None)
      .apply(highlight_assigned, axis=None)
      .set_properties(**{"text-align": "center"})
      .set_table_styles([
          {"selector": "th", "props": [("text-align", "center")]},
          {"selector": "td", "props": [("min-width", "3em"), ("height", "2.2em")]},
          {"selector": "table", "props": [("border-collapse", "collapse"),
                                          ("font-family", "sans-serif")]}
      ])
)


# ===== Affichage dans un notebook (Jupyter, VS Code, etc.) =====
# Dans un notebook, décommente la ligne suivante :
display(styler)

# ===== Export HTML autonome =====
#html_path = "tableau_scores_assignations.html"
#with open(html_path, "w", encoding="utf-8") as f:
#    f.write(styler.to_html())

#print(f"Fichier HTML généré : {html_path}")
# Out:
# <style  type="text/css" >
#     #T_8715c_ th {
#           text-align: center;
#     }    #T_8715c_ td {
#           min-width: 3em;
#           height: 2.2em;
#     }    #T_8715c_ table {
#           border-collapse: collapse;
#           font-family: sans-serif;
#     }#T_8715c_row0_col0,#T_8715c_row1_col5,#T_8715c_row2_col5,#T_8715c_row3_col1,#T_8715c_row4_col1,#T_8715c_row5_col2,#T_8715c_row6_col5,#T_8715c_row7_col0,#T_8715c_row8_col0,#T_8715c_row9_col1,#T_8715c_row11_col2,#T_8715c_row17_col1,#T_8715c_row18_col5,#T_8715c_row19_col0,#T_8715c_row20_col0,#T_8715c_row22_col2{
#             background-color:  #50a254;
#             color:  #000000;
#             text-align:  center;
#         }#T_8715c_row0_col1,#T_8715c_row1_col3,#T_8715c_row2_col2,#T_8715c_row3_col5,#T_8715c_row4_col2,#T_8715c_row5_col5,#T_8715c_row6_col1,#T_8715c_row7_col1,#T_8715c_row8_col3,#T_8715c_row9_col2,#T_8715c_row10_col4,#T_8715c_row11_col3,#T_8715c_row12_col0,#T_8715c_row13_col2,#T_8715c_row14_col4,#T_8715c_row15_col0,#T_8715c_row16_col1,#T_8715c_row17_col3,#T_8715c_row18_col4,#T_8715c_row19_col2,#T_8715c_row20_col1,#T_8715c_row21_col1,#T_8715c_row22_col0{
#             background-color:  #c9e6ca;
#             color:  #000000;
#             text-align:  center;
#         }#T_8715c_row0_col2,#T_8715c_row1_col2,#T_8715c_row2_col3,#T_8715c_row3_col0,#T_8715c_row4_col4,#T_8715c_row5_col3,#T_8715c_row6_col0,#T_8715c_row7_col5,#T_8715c_row8_col2,#T_8715c_row9_col4,#T_8715c_row10_col3,#T_8715c_row11_col4,#T_8715c_row12_col5,#T_8715c_row13_col4,#T_8715c_row14_col5,#T_8715c_row15_col4,#T_8715c_row16_col3,#T_8715c_row17_col5,#T_8715c_row18_col2,#T_8715c_row19_col1,#T_8715c_row20_col2,#T_8715c_row21_col5,#T_8715c_row22_col4{
#             background-color:  #98d19b;
#             color:  #000000;
#             text-align:  center;
#         }#T_8715c_row0_col3,#T_8715c_row1_col4,#T_8715c_row2_col1,#T_8715c_row3_col2,#T_8715c_row4_col5,#T_8715c_row5_col4,#T_8715c_row6_col3,#T_8715c_row7_col4,#T_8715c_row8_col1,#T_8715c_row9_col3,#T_8715c_row10_col0,#T_8715c_row11_col1,#T_8715c_row12_col2,#T_8715c_row13_col3,#T_8715c_row14_col3,#T_8715c_row15_col2,#T_8715c_row16_col0,#T_8715c_row17_col0,#T_8715c_row18_col3,#T_8715c_row19_col5,#T_8715c_row20_col3,#T_8715c_row21_col4,#T_8715c_row22_col3{
#             background-color:  #ffffff;
#             color:  #000000;
#             text-align:  center;
#         }#T_8715c_row0_col4,#T_8715c_row1_col0,#T_8715c_row2_col4,#T_8715c_row3_col3,#T_8715c_row4_col3,#T_8715c_row5_col0,#T_8715c_row6_col4,#T_8715c_row7_col2,#T_8715c_row8_col4,#T_8715c_row9_col5,#T_8715c_row10_col1,#T_8715c_row11_col0,#T_8715c_row12_col4,#T_8715c_row13_col5,#T_8715c_row14_col2,#T_8715c_row15_col1,#T_8715c_row16_col2,#T_8715c_row17_col4,#T_8715c_row18_col1,#T_8715c_row19_col3,#T_8715c_row20_col5,#T_8715c_row21_col3,#T_8715c_row22_col1{
#             background-color:  #73c076;
#             color:  #000000;
#             text-align:  center;
#         }#T_8715c_row0_col5,#T_8715c_row1_col1,#T_8715c_row2_col0,#T_8715c_row3_col4,#T_8715c_row4_col0,#T_8715c_row5_col1,#T_8715c_row6_col2,#T_8715c_row7_col3,#T_8715c_row8_col5,#T_8715c_row9_col0,#T_8715c_row11_col5,#T_8715c_row17_col2,#T_8715c_row18_col0,#T_8715c_row19_col4,#T_8715c_row20_col4,#T_8715c_row22_col5{
#             background-color:  #2e7d32;
#             color:  #f1f1f1;
#             border:  3px solid black;
#             text-align:  center;
#         }#T_8715c_row10_col2,#T_8715c_row12_col3,#T_8715c_row13_col1,#T_8715c_row14_col1,#T_8715c_row15_col3,#T_8715c_row16_col4,#T_8715c_row21_col2{
#             background-color:  #50a254;
#             color:  #000000;
#             border:  3px solid black;
#             text-align:  center;
#         }#T_8715c_row10_col5,#T_8715c_row12_col1,#T_8715c_row13_col0,#T_8715c_row14_col0,#T_8715c_row15_col5,#T_8715c_row16_col5,#T_8715c_row21_col0{
#             background-color:  #2e7d32;
#             color:  #f1f1f1;
#             text-align:  center;
#         }</style><table id="T_8715c_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >P1</th>        <th class="col_heading level0 col1" >P2</th>        <th class="col_heading level0 col2" >P3</th>        <th class="col_heading level0 col3" >P4</th>        <th class="col_heading level0 col4" >P5</th>        <th class="col_heading level0 col5" >P6</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_8715c_level0_row0" class="row_heading level0 row0" >E1</th>
#                         <td id="T_8715c_row0_col0" class="data row0 col0" >5</td>
#                         <td id="T_8715c_row0_col1" class="data row0 col1" >2</td>
#                         <td id="T_8715c_row0_col2" class="data row0 col2" >3</td>
#                         <td id="T_8715c_row0_col3" class="data row0 col3" >1</td>
#                         <td id="T_8715c_row0_col4" class="data row0 col4" >4</td>
#                         <td id="T_8715c_row0_col5" class="data row0 col5" >6</td>
#             </tr>
#             <tr>
#                         <th id="T_8715c_level0_row1" class="row_heading level0 row1" >E2</th>
#                         <td id="T_8715c_row1_col0" class="data row1 col0" >4</td>
#                         <td id="T_8715c_row1_col1" class="data row1 col1" >6</td>
#                         <td id="T_8715c_row1_col2" class="data row1 col2" >3</td>
#                         <td id="T_8715c_row1_col3" class="data row1 col3" >2</td>
#                         <td id="T_8715c_row1_col4" class="data row1 col4" >1</td>
#                         <td id="T_8715c_row1_col5" class="data row1 col5" >5</td>
#             </tr>
#             <tr>
#                         <th id="T_8715c_level0_row2" class="row_heading level0 row2" >E3</th>
#                         <td id="T_8715c_row2_col0" class="data row2 col0" >6</td>
#                         <td id="T_8715c_row2_col1" class="data row2 col1" >1</td>
#                         <td id="T_8715c_row2_col2" class="data row2 col2" >2</td>
#                         <td id="T_8715c_row2_col3" class="data row2 col3" >3</td>
#                         <td id="T_8715c_row2_col4" class="data row2 col4" >4</td>
#                         <td id="T_8715c_row2_col5" class="data row2 col5" >5</td>
#             </tr>
#             <tr>
#                         <th id="T_8715c_level0_row3" class="row_heading level0 row3" >E4</th>
#                         <td id="T_8715c_row3_col0" class="data row3 col0" >3</td>
#                         <td id="T_8715c_row3_col1" class="data row3 col1" >5</td>
#                         <td id="T_8715c_row3_col2" class="data row3 col2" >1</td>
#                         <td id="T_8715c_row3_col3" class="data row3 col3" >4</td>
#                         <td id="T_8715c_row3_col4" class="data row3 col4" >6</td>
#                         <td id="T_8715c_row3_col5" class="data row3 col5" >2</td>
#             </tr>
#             <tr>
#                         <th id="T_8715c_level0_row4" class="row_heading level0 row4" >E5</th>
#                         <td id="T_8715c_row4_col0" class="data row4 col0" >6</td>
#                         <td id="T_8715c_row4_col1" class="data row4 col1" >5</td>
#                         <td id="T_8715c_row4_col2" class="data row4 col2" >2</td>
#                         <td id="T_8715c_row4_col3" class="data row4 col3" >4</td>
#                         <td id="T_8715c_row4_col4" class="data row4 col4" >3</td>
#                         <td id="T_8715c_row4_col5" class="data row4 col5" >1</td>
#             </tr>
#             <tr>
#                         <th id="T_8715c_level0_row5" class="row_heading level0 row5" >E6</th>
#                         <td id="T_8715c_row5_col0" class="data row5 col0" >4</td>
#                         <td id="T_8715c_row5_col1" class="data row5 col1" >6</td>
#                         <td id="T_8715c_row5_col2" class="data row5 col2" >5</td>
#                         <td id="T_8715c_row5_col3" class="data row5 col3" >3</td>
#                         <td id="T_8715c_row5_col4" class="data row5 col4" >1</td>
